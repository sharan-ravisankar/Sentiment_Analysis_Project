# %%
import pandas 
import pickle
import streamlit as st
import warnings
from sklearn.base import BaseEstimator, TransformerMixin
from text import TextPreprocessor
warnings.filterwarnings('ignore')

# %%
model = pickle.load(open('nlp.pkl','rb'))

# %%
st.title("🧠 Sentiment Analysis Web App")
st.write("Enter any text or customer review below to analyze its **sentiment** using your trained NLP model.")

user_input = st.text_area("💬 Enter text here:", height=150, placeholder="Type a review or feedback...")

if st.button("🔍 Analyze Sentiment"):
    if user_input.strip() == "":
        st.warning("Please enter some text to analyze.")
    else:       
        prediction = model.predict(pd.Series([user_input]))[0]

        if prediction.lower() == "positive":
            st.success(f"✅ Predicted Sentiment: {prediction}")
        elif prediction.lower() == "negative":
            st.error(f"❌ Predicted Sentiment: {prediction}")
        else:
            st.info(f"🤔 Predicted Sentiment: {prediction}")
# Out:
# 2025-11-14 13:02:39.632 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 13:02:39.791
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\SARAN\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-11-14 13:02:39.792 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 13:02:39.794 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 13:02:39.794 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 13:02:39.796 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 13:02:39.796 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 13:02:39.797 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 13:02:39.798 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 13:02:39.799 Session state does not function when running a script without `streamlit run`
# 2025-11-14 13:02:39.800 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 13:02:39.801 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 13:02:39.803 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 13:02:39.805 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 13:02:39.806 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 13:02:39.807 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-14 13:02:39.808 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
